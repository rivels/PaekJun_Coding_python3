# %%
a=int(input())
if (a//5==0 and a//3==0) or (a-(a//5))/3!=0:
    print(-1)
else:
    A=a//5
    B=A//3
    print(A+B)

# %%
a=int(input())
five=a//5 #5로 나눈 몫
a=a-(five*5)
three=a//3 #3으로 나눈 몫
a=a-(three*3)



if (five==0 and three==0):
    print(-1)
else:
    print(five+three)

# %%
a=int(input())
F=a//5
a5=a-(F*5)
T=a5//3
a3=a5-(T*3)

if a3!=0:
    if a//3
    print(-1)
else:
    print(F+T)

# %%
a=int(input())
b=0
while True:
    if a%5==0:
        print((a//5)+b)
        print(a//5,b)
        break
    elif a<0:
        print(-1)
        break
    
    else:
        a-=3
        b+=1
        
'''
가장 먼저 체크해야 할 사항은 5로 나누어떨어져 나머지가 0인지에 대한 여부
그래서 만약 나누어떨어지면 그걸로 해결이고
그렇지 않다면 3kg짜리로 빼가면서 계속 5로 나누어 떨어지는지를 확인하는
반복문을 작성하면 해결할 수 있는 문제.
'''

# %%
'''
등비가 2인 등비수열
1은 1번
7이하는 2번
19이하는 3번
37이하는 4번
61이하는 5번
1 2 3  4  5  6  7 ...
1 7 19 37 61 91 127 ...
 6 12 18 24 30 36 42 ...

'''

# %%
n=int(input())
c=1
s=6
while True:
    if n<=0 or n==1:
        print(c)
        break
    n-=s
    s+=6
    c+=1

# %%
a=1
n=6
for i in range(0,20):
    print(a,i+1)
    a+=n
    n+=6

# %%
'''
1,2~3,4~6,7~10,11~15,16~21,...
1  1   2  3    4     5

1 2 6 7 15 16 28 29  45 46  66 ...
   4   8     12    16     20   ...
   
1  2  6  7  15 16 28 29 45
3  5  8  14 17 27 30 44
4  9  13 18 26 31 43
10 12 19 25 32 42
11 20 24 33 41
21 23 34 40
22 35 39
36 38
37
'''

# %%
c,N=map(int,input().split())
CL=list(map(int,input().split()))
k=0
for i in range(0,c-2):
    for j in range(1,c-1):
        for k in range(2,c):
            print(CL[i],CL[j],CL[k])
            S=CL[i]+CL[j]+CL[k]
            if S==N:
                print(S)

            else:
                S=0
        if S==N:
                break
    if S==N:
                break
# Out:
# 5 21
# 5 6 7 8 9
# 5 6 7
# 5 6 8
# 5 6 9
# 5 7 7
# 5 7 8
# 5 7 9
# 21

# %%
import sys
sys.setrecursionlimit(1000000)

c,N=map(int,input().split())
CL=list(map(int,input().split()))
k=0
U=[]
for i in range(0,c):
    for j in range(0,c):
        for k in range(0,c):
            if i!=j and i!=k and j!=k:
                S=CL[i]+CL[j]+CL[k]
                if S==N:
                    break
                else:
                    U.append(abs(N-S))
            if S==N:
                break
        if S==N:
            break
if S==N:
    print(S)
else:
    print(N-min(U))
# Out:
# 50 500
# 93 181 245 214 315 36 185 138 216 295 93 181 245 214 315 36 185 138 216 295 93 181 245 214 315 36 185 138 216 295 93 181 245 214 315 36 185 138 216 295 93 181 245 214 315 36 185 138 216 295
# 500

# %%
U
# Out:
# [-19,
#  12,
#  -89,
#  190,
#  41,
#  88,
#  10,
#  -69,
#  -19,
#  -52,
#  -153,
#  126,
#  -23,
#  24,
#  -54,
#  -133,
#  12,
#  -52,
#  -122,
#  157,
#  8,
#  55,
#  -23,
#  -102,
#  -89,
#  -153,
#  -122,
#  56,
#  -93,
#  -46,
#  -124,
#  -203,
#  190,
#  126,
#  157,
#  56,
#  186,
#  233,
#  155,
#  76,
#  41,
#  -23,
#  8,
#  -93,
#  186,
#  84,
#  6,
#  -73,
#  88,
#  24,
#  55,
#  -46,
#  233,
#  84,
#  53,
#  -26,
#  10,
#  -54,
#  -23,
#  -124,
#  155,
#  6,
#  53,
#  -104,
#  -69,
#  -133,
#  -102,
#  -203,
#  76,
#  -73,
#  -26,
#  -104,
#  -19,
#  12,
#  -89,
#  190,
#  41,
#  88,
#  10,
#  -69,
#  -19,
#  -140,
#  -241,
#  38,
#  -111,
#  -64,
#  -142,
#  -221,
#  12,
#  -140,
#  -210,
#  69,
#  -80,
#  -33,
#  -111,
#  -190,
#  -89,
#  -241,
#  -210,
#  -32,
#  -181,
#  -134,
#  -212,
#  -291,
#  190,
#  38,
#  69,
#  -32,
#  98,
#  145,
#  67,
#  -12,
#  41,
#  -111,
#  -80,
#  -181,
#  98,
#  -4,
#  -82,
#  -161,
#  88,
#  -64,
#  -33,
#  -134,
#  145,
#  -4,
#  -35,
#  -114,
#  10,
#  -142,
#  -111,
#  -212,
#  67,
#  -82,
#  -35,
#  -192,
#  -69,
#  -221,
#  -190,
#  -291,
#  -12,
#  -161,
#  -114,
#  -192,
#  -19,
#  -52,
#  -153,
#  126,
#  -23,
#  24,
#  -54,
#  -133,
#  -19,
#  -140,
#  -241,
#  38,
#  -111,
#  -64,
#  -142,
#  -221,
#  -52,
#  -140,
#  -274,
#  5,
#  -144,
#  -97,
#  -175,
#  -254,
#  -153,
#  -241,
#  -274,
#  -96,
#  -245,
#  -198,
#  -276,
#  -355,
#  126,
#  38,
#  5,
#  -96,
#  34,
#  81,
#  3,
#  -76,
#  -23,
#  -111,
#  -144,
#  -245,
#  34,
#  -68,
#  -146,
#  -225,
#  24,
#  -64,
#  -97,
#  -198,
#  81,
#  -68,
#  -99,
#  -178,
#  -54,
#  -142,
#  -175,
#  -276,
#  3,
#  -146,
#  -99,
#  -256,
#  -133,
#  -221,
#  -254,
#  -355,
#  -76,
#  -225,
#  -178,
#  -256,
#  12,
#  -52,
#  -122,
#  157,
#  8,
#  55,
#  -23,
#  -102,
#  12,
#  -140,
#  -210,
#  69,
#  -80,
#  -33,
#  -111,
#  -190,
#  -52,
#  -140,
#  -274,
#  5,
#  -144,
#  -97,
#  -175,
#  -254,
#  -122,
#  -210,
#  -274,
#  -65,
#  -214,
#  -167,
#  -245,
#  -324,
#  157,
#  69,
#  5,
#  -65,
#  65,
#  112,
#  34,
#  -45,
#  8,
#  -80,
#  -144,
#  -214,
#  65,
#  -37,
#  -115,
#  -194,
#  55,
#  -33,
#  -97,
#  -167,
#  112,
#  -37,
#  -68,
#  -147,
#  -23,
#  -111,
#  -175,
#  -245,
#  34,
#  -115,
#  -68,
#  -225,
#  -102,
#  -190,
#  -254,
#  -324,
#  -45,
#  -194,
#  -147,
#  -225,
#  -89,
#  -153,
#  -122,
#  56,
#  -93,
#  -46,
#  -124,
#  -203,
#  -89,
#  -241,
#  -210,
#  -32,
#  -181,
#  -134,
#  -212,
#  -291,
#  -153,
#  -241,
#  -274,
#  -96,
#  -245,
#  -198,
#  -276,
#  -355,
#  -122,
#  -210,
#  -274,
#  -65,
#  -214,
#  -167,
#  -245,
#  -324,
#  56,
#  -32,
#  -96,
#  -65,
#  -36,
#  11,
#  -67,
#  -146,
#  -93,
#  -181,
#  -245,
#  -214,
#  -36,
#  -138,
#  -216,
#  -295,
#  -46,
#  -134,
#  -198,
#  -167,
#  11,
#  -138,
#  -169,
#  -248,
#  -124,
#  -212,
#  -276,
#  -245,
#  -67,
#  -216,
#  -169,
#  -326,
#  -203,
#  -291,
#  -355,
#  -324,
#  -146,
#  -295,
#  -248,
#  -326,
#  190,
#  126,
#  157,
#  56,
#  186,
#  233,
#  155,
#  76,
#  190,
#  38,
#  69,
#  -32,
#  98,
#  145,
#  67,
#  -12,
#  126,
#  38,
#  5,
#  -96,
#  34,
#  81,
#  3,
#  -76,
#  157,
#  69,
#  5,
#  -65,
#  65,
#  112,
#  34,
#  -45,
#  56,
#  -32,
#  -96,
#  -65,
#  -36,
#  11,
#  -67,
#  -146,
#  186,
#  98,
#  34,
#  65,
#  -36,
#  141,
#  63,
#  -16,
#  233,
#  145,
#  81,
#  112,
#  11,
#  141,
#  110,
#  31,
#  155,
#  67,
#  3,
#  34,
#  -67,
#  63,
#  110,
#  -47,
#  76,
#  -12,
#  -76,
#  -45,
#  -146,
#  -16,
#  31,
#  -47,
#  41,
#  -23,
#  8,
#  -93,
#  186,
#  84,
#  6,
#  -73,
#  41,
#  -111,
#  -80,
#  -181,
#  98,
#  -4,
#  -82,
#  -161,
#  -23,
#  -111,
#  -144,
#  -245,
#  34,
#  -68,
#  -146,
#  -225,
#  8,
#  -80,
#  -144,
#  -214,
#  65,
#  -37,
#  -115,
#  -194,
#  -93,
#  -181,
#  -245,
#  -214,
#  -36,
#  -138,
#  -216,
#  -295,
#  186,
#  98,
#  34,
#  65,
#  -36,
#  141,
#  63,
#  -16,
#  84,
#  -4,
#  -68,
#  -37,
#  -138,
#  141,
#  -39,
#  -118,
#  6,
#  -82,
#  -146,
#  -115,
#  -216,
#  63,
#  -39,
#  -196,
#  -73,
#  -161,
#  -225,
#  -194,
#  -295,
#  -16,
#  -118,
#  -196,
#  88,
#  24,
#  55,
#  -46,
#  233,
#  84,
#  53,
#  -26,
#  88,
#  -64,
#  -33,
#  -134,
#  145,
#  -4,
#  -35,
#  -114,
#  24,
#  -64,
#  -97,
#  -198,
#  81,
#  -68,
#  -99,
#  -178,
#  55,
#  -33,
#  -97,
#  -167,
#  112,
#  -37,
#  -68,
#  -147,
#  -46,
#  -134,
#  -198,
#  -167,
#  11,
#  -138,
#  -169,
#  -248,
#  233,
#  145,
#  81,
#  112,
#  11,
#  141,
#  110,
#  31,
#  84,
#  -4,
#  -68,
#  -37,
#  -138,
#  141,
#  -39,
#  -118,
#  53,
#  -35,
#  -99,
#  -68,
#  -169,
#  110,
#  -39,
#  -149,
#  -26,
#  -114,
#  -178,
#  -147,
#  -248,
#  31,
#  -118,
#  -149,
#  10,
#  -54,
#  -23,
#  -124,
#  155,
#  6,
#  53,
#  -104,
#  10,
#  -142,
#  -111,
#  -212,
#  67,
#  -82,
#  -35,
#  -192,
#  -54,
#  -142,
#  -175,
#  -276,
#  3,
#  -146,
#  -99,
#  -256,
#  -23,
#  -111,
#  -175,
#  -245,
#  34,
#  -115,
#  -68,
#  -225,
#  -124,
#  -212,
#  -276,
#  -245,
#  -67,
#  -216,
#  -169,
#  -326,
#  155,
#  67,
#  3,
#  34,
#  -67,
#  63,
#  110,
#  -47,
#  6,
#  -82,
#  -146,
#  -115,
#  -216,
#  63,
#  -39,
#  -196,
#  53,
#  -35,
#  -99,
#  -68,
#  -169,
#  110,
#  -39,
#  -149,
#  -104,
#  -192,
#  -256,
#  -225,
#  -326,
#  -47,
#  -196,
#  -149,
#  -69,
#  -133,
#  -102,
#  -203,
#  76,
#  -73,
#  -26,
#  -104,
#  -69,
#  -221,
#  -190,
#  -291,
#  -12,
#  -161,
#  -114,
#  -192,
#  -133,
#  -221,
#  -254,
#  -355,
#  -76,
#  -225,
#  -178,
#  -256,
#  -102,
#  -190,
#  -254,
#  -324,
#  -45,
#  -194,
#  -147,
#  -225,
#  -203,
#  -291,
#  -355,
#  -324,
#  -146,
#  -295,
#  -248,
#  -326,
#  76,
#  -12,
#  -76,
#  -45,
#  -146,
#  -16,
#  31,
#  -47,
#  -73,
#  -161,
#  -225,
#  -194,
#  -295,
#  -16,
#  -118,
#  -196,
#  -26,
#  -114,
#  -178,
#  -147,
#  -248,
#  31,
#  -118,
#  -149,
#  -104,
#  -192,
#  -256,
#  -225,
#  -326,
#  -47,
#  -196,
#  -149]

# %%
N
# Out:
# 21

# %%
S
# Out:
# 21

# %%
U
# Out:
# [0]
